# %% [markdown]
# # ER pipeline using Few Shot Prompting
#
# - Input : NER pipeline results + the corresponding text to annotated entities
# - Output: Extracted interactions between the annotated entities + Corresponding Knowledge Graph
# - Evaluation of ER : Being done by Experts in Ecology and Biodiversity

# %% [markdown]
# ### Load Model and Needed Packages

# %%
# Import necessary libraries
import os
import json
import pandas as pd
from tqdm import tqdm
import re
import logging
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI


logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

os.environ["OPENAI_API_KEY"] = ""  
os.environ["OPENAI_API_BASE"] = "https://api.deepinfra.com/v1/openai"

# %% [markdown]
# ### ER Pipeline

# %%
class SpeciesRelationshipExtractor:
    """Extract ecological relationships between species from text with NER results."""

    def __init__(self, model_name="meta-llama/Llama-3.3-70B-Instruct", temperature=0.1, batch_size=10, 
                 confidence_threshold=0.5, debug=False):
        self.model_name = model_name
        self.temperature = temperature
        self.batch_size = batch_size
        self.confidence_threshold = confidence_threshold
        self.debug = debug

        self.interaction_df = None
        self.interaction_details = {}
        self.interaction_to_iri = {}

        self.llm = ChatOpenAI(model_name=model_name, temperature=temperature)
        self.prompt_template = self._create_few_shot_prompt()

        logger.info(f"Initialized SpeciesRelationshipExtractor with model: {model_name}, temp: {temperature}")

    def _format_relationship_types(self):
        formatted = []
        for interaction, details in self.interaction_details.items():
            if 'source' in details and 'target' in details:
                description = f"{interaction}: {details['source']} → {details['target']}"
            else:
                description = interaction
            formatted.append(f"- {description}")
        return "\n".join(formatted)

    def load_interaction_types(self, csv_path):
        try:
            df = pd.read_csv(csv_path)
            logger.info(f"Loaded interaction types with {len(df)} rows")
            interaction_details = {}
            interaction_to_iri = {}
            for _, row in df.iterrows():
                interaction = row['interaction']
                interaction_details[interaction] = {
                    'source': row['source'],
                    'target': row['target'],
                    'termIRI': row['termIRI']
                }
                if 'termIRI' in row:
                    interaction_to_iri[interaction] = row['termIRI']
            self.interaction_df = df
            self.interaction_details = interaction_details
            self.interaction_to_iri = interaction_to_iri
            return df, interaction_details, interaction_to_iri
        except Exception as e:
            logger.error(f"Error loading interaction types: {str(e)}")
            return None, {}, {}

    def _create_few_shot_prompt(self):
        template = """
You are an expert in extracting ecological relationships between species entities.  
Your task is to identify whether there is a specific interaction between the annotated entities in the given text.

Only use the following interaction types, grouped by category:

Predation:  
- eats, eatenby, kills, killedby, preyson, preyeduponby  

Competition:  
- allelopathof, competeswith  

Mutualism:  
- pollinates, pollinatedby, mutualistof, symbiontof, providesnutrientsfor, acquiresnutrientsfrom  

Commensalism:  
- commensalistof, epiphyteof, hasepiphyte, flowersvisitedby, visitsflowersof, dispersalvectorof, hasdispersalvector  

Parasitism:  
- parasiteof, hasparasite, hostof, hashost, parasitoidof, hasparasitoid, endoparasiteof, hasendoparasite, pathogenof, haspathogen, ectoparasiteof, hasectoparasite  

Neutral:  
- ecologicallyrelatedto, cooccurswith, coroostswith, interactswith, adjacentto, hashabitat, createshabitatfor, vectorof, hasvector  

Use `interactswith` **only** when a relation is likely but not explicitly stated (e.g., co-occurrence in ecological context).

If no specific relation is mentioned, do not assign one.

---

### Examples

**Example 1 (Predation):**  
Text: "Brown trout (Salmo trutta) prey on native roundhead galaxias (Galaxias anomalus)."  
E1: Brown trout  
E2: roundhead galaxias  
relation: E1 preyson E2  
confidence: 0.9

**Example 2 (Parasitism):**  
Text: "The parasitic mite Varroa destructor has devastated honeybee (Apis mellifera) colonies."  
E1: Varroa destructor  
E2: Apis mellifera  
relation: E1 parasiteof E2  
confidence: 0.9

**Example 3 (Competition):**  
Text: "Oak trees (Quercus spp.) compete with maple trees (Acer spp.) for light."  
E1: Oak trees  
E2: maple trees  
relation: E1 competeswith E2  
confidence: 0.9

**Example 4 (Neutral / Fallback):**  
Text: "Barnacles are often found on whale skin."  
E1: barnacles  
E2: whales  
relation: E1 interactswith E2  
confidence: 0.8

**Example 5 (Negative - No relation):**  
Text: "Bald eagles and pine trees are found in the same national parks."  
E1: Bald eagles  
E2: pine trees  
relation: (No relationship detected.)

**Example 6 (Negative - Generic co-occurrence):**  
Text: "Blue whales and dolphins are both marine animals."  
E1: Blue whales  
E2: dolphins  
relation: (No relationship detected.)

**Example 7 (Predation):**  
Text: "Caterpillars of monarch butterflies (Danaus plexippus) feed on milkweed (Asclepias spp.)."  
E1: Danaus plexippus  
E2: Asclepias  
relation: E1 preyson E2  
confidence: 0.9

---

### Now apply to the following:

Text: {text}  
Entities:  
{entities}

Return only pairs with a clear interaction.  
For each, give:

E1: [entity 1]  
E2: [entity 2]  
relation: E1 [relation type] E2  
confidence: [0.0–1.0]

If there is no relationship, do not include that pair.

Do **not** create new entities or relations.  
Use only the given entity list and approved relation types.

"""
        return PromptTemplate(input_variables=["text", "entities", "interaction_types"], template=template)

    def _passes_entity_filter(self, text):
        return True

    def prepare_document(self, doc):
        filtered_entities = []
        for i, entity in enumerate(doc.get("entities", [])):
            new_entity = entity.copy()
            new_entity["id"] = len(filtered_entities)
            filtered_entities.append(new_entity)
        entity_list = "\n".join([
            f"Entity ID {e['id']}: \"{e['text']}\" (Type: {e.get('label', 'SPECIES')})" 
            for e in filtered_entities
        ])
        return {
            "document_id": doc.get("document_id", "unknown"),
            "text": doc.get("text", ""),
            "original_entities": doc.get("entities", []),
            "filtered_entities": filtered_entities,
            "entity_list": entity_list
        }

    def extract_relationships(self, prepared_doc):
        if len(prepared_doc["filtered_entities"]) < 2:
            return []
        doc_id = prepared_doc.get("document_id", "unknown")
        prompt_inputs = {
            "interaction_types": self._format_relationship_types(),
            "text": prepared_doc["text"],
            "entities": prepared_doc["entity_list"]
        }
        prompt = self.prompt_template.format(**prompt_inputs)
        try:
            response = self.llm.invoke(prompt)
            response_content = getattr(response, 'content', '')
            if self.debug:
                logger.info(f"Response preview: {response_content[:200]}")
            relationships = []
            relationship_pattern = r'E1:\s*([^\n]+)\s*\nE2:\s*([^\n]+)\s*\nrelation:\s*E1\s+(\w+)\s+E2\s*\nconfidence:\s*(0\.\d+|1\.0)'
            matches = re.findall(relationship_pattern, response_content)
            seen = set()
            for match in matches:
                source, target, rel, conf = map(str.strip, match)
                key = (source.lower(), target.lower(), rel)
                if key not in seen and float(conf) >= self.confidence_threshold:
                    seen.add(key)
                    relationships.append({
                        "source_text": source,
                        "target_text": target,
                        "relation": rel,
                        "confidence": float(conf)
                    })
            return relationships
        except Exception as e:
            logger.error(f"Error extracting relationships for doc {doc_id}: {str(e)}")
            return []

    def load_ner_results(self, ner_results_path):
        try:
            df = pd.read_csv(ner_results_path)
            documents = []
            for doc_id, group in df.groupby('doc_id'):
                content = group['content'].iloc[0] if 'content' in group.columns else ""
                entities = []
                for _, row in group.iterrows():
                    if pd.notna(row.get('start')) and pd.notna(row.get('end')) and pd.notna(row.get('Annotation Text')):
                        entity_text = row['Annotation Text']
                        if self._passes_entity_filter(entity_text):
                            entities.append({
                                'id': len(entities),
                                'text': entity_text,
                                'start': int(row['start']),
                                'end': int(row['end']),
                                'label': row.get('label', 'SPECIES')
                            })
                if entities:
                    documents.append({
                        'document_id': doc_id,
                        'text': content,
                        'entities': entities
                    })
            return documents
        except Exception as e:
            logger.error(f"Error loading NER results: {str(e)}")
            return []

    def process_documents(self, documents, output_path=None):
        results = []
        for i in range(0, len(documents), self.batch_size):
            batch = documents[i:i+self.batch_size]
            for doc in tqdm(batch):
                prepared_doc = self.prepare_document(doc)
                relationships = self.extract_relationships(prepared_doc)
                doc["relationships"] = relationships
                results.append(doc)
        if output_path:
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(results, f, indent=2)
        return results

    def run_pipeline(self, ner_results_path, output_path):
        documents = self.load_ner_results(ner_results_path)
        return self.process_documents(documents, output_path)

# %% [markdown]
# ### Run pipeline

# %%
ner_results_file = "./s800_results/llama3_1_FS_results_on_zoo/balanced_species_entities_positions.csv"
output_file = "./s800_results/RE_FS_Results/speciesinteractions_llama3_2_t07_conf03_b10_final_version_of_prompt.json"
model_name = "meta-llama/Llama-3.2-3B-Instruct"  
temperature = 0.7
batch_size = 10
confidence_threshold = 0.3

# Create the extractor with debug mode
extractor = SpeciesRelationshipExtractor(
    model_name=model_name,
    temperature=temperature,
    batch_size=batch_size,
    confidence_threshold=confidence_threshold,
    debug=True
)

# Run the pipeline
results = extractor.run_pipeline(ner_results_file, output_file)
# Out:
# 2025-06-26 16:58:38,656 - INFO - Initialized SpeciesRelationshipExtractor with model: meta-llama/Llama-3.2-3B-Instruct, temp: 0.7
# 2025-06-26 16:58:40,139 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:40,142 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Urochloa brizantha
# E2: Zea mays
# relation: Urochloa brizantha allelopathof Zea mays
# confidence: 0.9
#
# 2.
# 2025-06-26 16:58:41,167 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:41,170 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Dufourea maura
# E2: Achillea millefolium
# relation: Dufourea maura mutualistof Achillea millefolium
# 2025-06-26 16:58:42,131 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:42,135 - INFO - Response preview: Based on the given text, I've identified the following interaction:
#
# E1: Pseudexentera habrosana
# E2: Quercus wislizeni
# relation: E1 parasiteof E2
# confidence: 0.9
#
# This interaction is classified
# 2025-06-26 16:58:43,270 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:43,274 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Phaseolus vulgaris
# E2: Spodoptera frugiperda
# relation: Phaseolus vulgaris allelopathof Spodopt
# 2025-06-26 16:58:44,845 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:44,848 - INFO - Response preview: Based on the provided text, I identified the following clear interactions:
#
# 1. Entity ID 0: Andrena trizonata
# E1: Andrena trizonata
# E2: Loma
# relation: E1 mutualistof E2
# confidence: 0.9
#
# 2. Ent
# 2025-06-26 16:58:45,391 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:45,394 - INFO - Response preview: Based on the given text, I have identified the following interaction:
#
# E1: Macaria signaria
# E2: Picea
# relation: E1 eats E2
# confidence: 0.9
# 2025-06-26 16:58:46,443 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:46,445 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Grona ramosissima
# E2: Striga hermonthica
# relation: Grona ramosissima competeswith Striga hermonthic
# 2025-06-26 16:58:47,596 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:47,600 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Desmodium intortum
# E2: Spodoptera frugiperda
# relation: E1 allelopathof E2
# confidence: 0.9
#
# This pai
# 2025-06-26 16:58:48,889 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:48,892 - INFO - Response preview: Based on the given text, I have identified the following interaction:
#
# Text: Aseptis ethnica has been identified as a consumer of Arctostaphylos patula, contributing to top-down control within the foo
# 2025-06-26 16:58:49,437 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:49,440 - INFO - Response preview: Based on the provided text, I identified the following interaction:
#
# E1: Closterocerus
# E2: Phillipsiella
# relation: E1 parasiteof E2
# confidence: 0.9
# 100%|███████████████████████████████████████████| 10/10 [00:10<00:00,  1.08s/it]
# 2025-06-26 16:58:50,554 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:50,558 - INFO - Response preview: After analyzing the given text, I identified the following pairs with a clear interaction:
#
# 1. E1: Epinotia emarginana
# E2: Arctostaphylos crustacea crustacea
# relation: E1 competeswith E2
# confide
# 2025-06-26 16:58:51,772 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:51,775 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Hydriomena nubilofasciata
# E2: Salix
# relation: E1 eats E2
# confidence: 0.9
#
# Note that the text does
# 2025-06-26 16:58:52,840 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:52,843 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Desmodium uncinatum
# E2: Sorghum
# relation: Desmodium uncinatum allelopathof Sorghum
# confidence:
# 2025-06-26 16:58:53,771 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:53,775 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Macaria signaria
# E2: Abies
# relation: Macaria signaria eats Abies
# confidence: 0.9
#
# This pair i
# 2025-06-26 16:58:55,516 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:55,518 - INFO - Response preview: Text: Closterocerus is known to parasitize Actornithophilus limosae, establishing a biologically intimate interaction that may negatively impact the host's physiology, behavior, or reproductive output
# 2025-06-26 16:58:56,552 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:56,556 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Quercus agrifolia
# relation: E1 interactswith E2
# confidence: 0.8
#
# This pair h
# 2025-06-26 16:58:57,717 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:57,723 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Epinotia emarginana
# E2: Arctostaphylos hookeri subsp. hookeri
# relation: E1 interactswith E2
# confidence:
# 2025-06-26 16:58:58,878 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:58,882 - INFO - Response preview: Based on the given text, I identified the following interactions:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Arbutus menziesii
# relation: E1 interactswith E2
# confidence: 0.8
#
# Note that the text mention
# 2025-06-26 16:58:59,646 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:58:59,649 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Syrrhaptoecus angulatus
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:00,919 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:00,922 - INFO - Response preview: Based on the given text, I have identified the following clear interactions:
#
# 1.
# E1: Desmodium uncinatum
# E2: Zea mays
# relation: E1 allelopathof E2
# confidence: 0.9
#
# 2.
# E1: Desmodium uncinatum
# 100%|███████████████████████████████████████████| 10/10 [00:11<00:00,  1.15s/it]
# 2025-06-26 16:59:01,997 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:02,000 - INFO - Response preview: After analyzing the text, I found the following clear interactions:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Quercus kelloggii
# relation: E1 interactswith E2
# confidence: 0.8
#
# This interaction is clas
# 2025-06-26 16:59:03,209 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:03,212 - INFO - Response preview: After analyzing the given text, I identified a clear interaction between the two entities. Here is the result:
#
# Text: The relationship between Lytechinus variegatus and Ophiothela mirabilis is an exam
# 2025-06-26 16:59:03,874 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:03,878 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Megascops asio
# E2: Rena dulcis
# relation: E1 commensalistof E2
# confidence: 0.9
# 2025-06-26 16:59:05,430 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:05,434 - INFO - Response preview: Based on the provided text, I have identified the following clear interactions:
#
# 1.
# E1: Desmodium incanum
# E2: Sorghum
# relation: Desmodium incanum allelopathof Sorghum
# confidence: 0.9
#
# This inte
# 2025-06-26 16:59:06,384 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:06,388 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Quercus turbinella
# relation: E1 parasiteof E2
# confidence: 0.9
#
# This
# 2025-06-26 16:59:07,402 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:07,406 - INFO - Response preview: Based on the provided text, I identified the following clear interactions:
#
# 1.
# E1: Phaseolus vulgaris
# E2: Zea mays
# relation: Phaseolus vulgaris competeswith Zea mays
# confidence: 0.9
#
# 2.
# E1: Ph
# 2025-06-26 16:59:08,717 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:08,720 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Perdita eremica
# E2: Funastrum hirtellum
# relation: Perdita eremica mutualistof Funastrum hirtel
# 2025-06-26 16:59:09,757 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:09,759 - INFO - Response preview: After analyzing the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Quercus
# relation: E1 interactswith E2
# confidence: 0.8
#
# Note that t
# 2025-06-26 16:59:10,855 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:10,858 - INFO - Response preview: Based on the provided text, I've identified the following interactions:
#
# 1. Entity ID 0: Desmodium uncinatum
# Entity ID 1: Striga hermonthica
# relation: Desmodium uncinatum allelopathof Striga hermo
# 2025-06-26 16:59:11,407 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:11,410 - INFO - Response preview: Based on the provided text, I identified the following interaction:
#
# E1: Closterocerus
# E2: Caligo ilcoxiens
# relation: E1 parasiteof E2
# confidence: 0.9
# 100%|███████████████████████████████████████████| 10/10 [00:10<00:00,  1.05s/it]
# 2025-06-26 16:59:13,097 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:13,101 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Hylodesmum repandum
# E2: Striga hermonthica
# relation: Hylodesmum repandum allelopathof Striga hermonthi
# 2025-06-26 16:59:13,849 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:13,852 - INFO - Response preview: Based on the provided text, I have identified the following interaction:
#
# E1: Macaria signaria
# E2: Tsuga canadensis
# relation: E1 eats E2
# confidence: 0.9
# 2025-06-26 16:59:14,750 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:14,753 - INFO - Response preview: Based on the provided text, I've identified the following interaction:
#
# **Entity 1:** Pseudexentera habrosana
# **Entity 2:** Quercus lobata
# **relation:** E1 parasiteof E2
# **confidence:** 0.9
#
# The
# 2025-06-26 16:59:15,881 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:15,884 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena chalybioides
# E2: Ranunculus
# relation: E1 mutualistof E2
# confidence: 0.9
#
# Note that th
# 2025-06-26 16:59:16,942 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:16,945 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Epinotia emarginana
# E2: Arctostaphylos nummularia nummularia
# relation: E1 competeswith E2
# confidence: 0.8
# 2025-06-26 16:59:17,798 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:17,802 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena hilaris
# E2: Conium maculatum
# relation: E1 mutualistof E2
# confidence: 0.9
#
# This relationshi
# 2025-06-26 16:59:18,522 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:18,525 - INFO - Response preview: Based on the provided text, I identified the following interactions:
#
# 1.
# E1: Closterocerus
# E2: Helicobasidium
# relation: E1 parasiteof E2
# confidence: 0.9
#
# This interaction is clearly stated as a
# 2025-06-26 16:59:19,303 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:19,307 - INFO - Response preview: Based on the given text, I've identified the following interactions:
#
# 1. E1: Andrena chalybioides
# E2: Hypochaeris
# relation: E1 mutualistof E2
# confidence: 0.9
#
# This interaction is clear and expli
# 2025-06-26 16:59:20,206 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:20,210 - INFO - Response preview: Based on the provided text, the following pairs with a clear interaction are identified:
#
# 1.
# E1: Rena dulcis
# E2: Megascops asio
# relation: Rena dulcis commensalistof Megascops asio
# confidence: 0
# 2025-06-26 16:59:21,466 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:21,469 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Aseptis ethnica
# E2: Arbutus
# relation: E1 eats E2
# confidence: 0.9
#
# Note that the text mentions "
# 100%|███████████████████████████████████████████| 10/10 [00:10<00:00,  1.01s/it]
# 2025-06-26 16:59:22,438 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:22,442 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena argemonis
# E2: Argemone hispida
# relation: Andrena argemonis mutualistof Argemone hispida
# 2025-06-26 16:59:23,041 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:23,044 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena confederata
# E2: Abundance
# relation: E1 mutualistof E2
# confidence: 0.9
# 2025-06-26 16:59:24,175 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:24,178 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Pseudopanurgus parvus
# E2: Asiminia triloba
# relation: Pseudopanurgus parvus mutualistof Asiminia
# 2025-06-26 16:59:25,118 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:25,122 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Syndesmis collongistyla
# E2: Lytechinus williamsi
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This pai
# 2025-06-26 16:59:25,733 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:25,736 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Syndesmis collongistyla
# E2: Echinometra lucunter
# relation: E1 commensalistof E2
# confidence: 0.
# 2025-06-26 16:59:26,761 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:26,764 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Lytechinus variegatus
# E2: Gnathophylloides
# relation: E1 commensalistof E2
# confidence: 0.9
#
# Th
# 2025-06-26 16:59:27,603 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:27,606 - INFO - Response preview: After analyzing the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Quercus dumosa
# relation: E1 parasiteof E2
# confidence: 0.9
#
# Note th
# 2025-06-26 16:59:28,490 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:28,493 - INFO - Response preview: After analyzing the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Syndesmis collongistyla
# E2: Echinometra viridis
# relation: E1 commensalistof E2
# confidence: 0.9
# 2025-06-26 16:59:29,320 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:29,324 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Grona ramosissima
# E2: Sorghum
# relation: Grona ramosissima allelopathof Sorghum
# confidence: 0.9
#
# 2.
# 2025-06-26 16:59:30,415 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:30,419 - INFO - Response preview: After analyzing the text, I identified the following clear interaction:
#
# Text: The relationship between Syndesmis collongistyla and Tripneustes ventricosus is an example of commensalism, where Syndesm
# 100%|███████████████████████████████████████████| 10/10 [00:08<00:00,  1.12it/s]
# 2025-06-26 16:59:31,012 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:31,015 - INFO - Response preview: After analyzing the text, I identified the following interaction:
#
# E1: Closterocerus
# E2: Colpocephalum megalops
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:31,865 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:31,868 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena hilaris
# E2: Abundance
# relation: Andrena hilaris mutualistof Abundance
# confidence: 0.9
#
# This
# 2025-06-26 16:59:32,716 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:32,719 - INFO - Response preview: Based on the provided text, I've identified the following clear interactions:
#
# 1.
# E1: Chrysocharis
# E2: Sorbus commixta
# relation: E1 mutualistof E2
# confidence: 0.9
#
# 2.
# E1: Sorbus commixta
# E
# 2025-06-26 16:59:33,304 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:33,307 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Oxylipeurus hoogstraali
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:33,812 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:33,815 - INFO - Response preview: Based on the given text, I have identified the following interaction:
#
# E1: Closterocerus
# E2: Codinaea
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:34,838 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:34,841 - INFO - Response preview: Based on the provided text, the following pairs with a clear interaction are identified:
#
# 1.
# E1: Hydriomena nubilofasciata
# E2: Quercus garryana
# relation: E1 eats E2
# confidence: 0.9
#
# 2.
# E1: H
# 2025-06-26 16:59:35,757 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:35,761 - INFO - Response preview: Based on the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Macaria signaria
# E2: Larix laricina
# relation: E1 eats E2
# confidence: 0.9
#
# Note that this pair is clas
# 2025-06-26 16:59:36,651 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:36,656 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Buteo buteo
# E2: Picea sitchensis
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This pair is an example
# 2025-06-26 16:59:37,589 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:37,592 - INFO - Response preview: Based on the provided text, I have identified the following clear interactions:
#
# 1.
# E1: Andrena chalybioides
# E2: Micranthes integrifolia
# relation: E1 mutualistof E2
# confidence: 0.9
#
# This intera
# 2025-06-26 16:59:38,553 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:38,556 - INFO - Response preview: Based on the provided text, I identified the following clear interactions:
#
# 1.
# E1: Hylodesmum repandum
# E2: Sorghum
# relation: Hylodesmum repandum competeswith Sorghum
# confidence: 0.9
#
# 2.
# E1:
# 100%|███████████████████████████████████████████| 10/10 [00:08<00:00,  1.23it/s]
# 2025-06-26 16:59:39,617 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:39,620 - INFO - Response preview: Based on the provided text, I've identified the following interactions:
#
# 1.
# E1: Epinotia emarginana
# E2: Rhododendron columbianum
# relation: E1 interactswith E2
# confidence: 0.9
#
# Note that the tex
# 2025-06-26 16:59:40,237 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:40,240 - INFO - Response preview: Based on the provided text, I have identified the following interaction:
#
# E1: Hydriomena nubilofasciata
# E2: Salix cinerea
# relation: E1 eats E2
# confidence: 0.9
# 2025-06-26 16:59:41,555 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:41,558 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Aseptis ethnica
# E2: Arctostaphylos pungens
# relation: E1 eats E2
# confidence: 0.9
#
# 2.
# E1: Aseptis
# 2025-06-26 16:59:43,315 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:43,318 - INFO - Response preview: Based on the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Urochloa eminii
# E2: Spodoptera frugiperda
# relation: Urochloa eminii allelopathof Spodoptera frugiperda
# 2025-06-26 16:59:44,347 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:44,351 - INFO - Response preview: Based on the provided text, the following pairs with clear interactions are identified:
#
# 1.
# E1: Desmodium intortum
# E2: Zea mays
# relation: Desmodium intortum allelopathof Zea mays
# confidence: 0.
# 2025-06-26 16:59:45,371 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:45,374 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Falco tinnunculus
# E2: Picea sitchensis
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This pai
# 2025-06-26 16:59:46,512 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:46,515 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Phyllonorycter quercifoliella
# relation: E1 parasiteof E2
# confidence: 0.9
#
# This pa
# 2025-06-26 16:59:48,134 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:48,138 - INFO - Response preview: After analyzing the text, I found a clear interaction between the two entities. Here is the result:
#
# Text: Ecological observations report that Epinotia emarginana interacts with Arbutus menziesii with
# 2025-06-26 16:59:49,102 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:49,105 - INFO - Response preview: Based on the provided text, I have identified the following clear interactions:
#
# 1.
# E1: Macaria signaria
# E2: Pinus
# relation: E1 eats E2
# confidence: 0.9
#
# This interaction is classified as Predat
# 2025-06-26 16:59:49,764 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:49,768 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Vesiculomyces
# relation: E1 parasiteof E2
# confidence: 0.9
# 100%|███████████████████████████████████████████| 10/10 [00:11<00:00,  1.12s/it]
# 2025-06-26 16:59:50,316 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:50,320 - INFO - Response preview: Based on the provided text, I have identified the following interaction:
#
# E1: Closterocerus
# E2: Acanthonitschkea
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:51,123 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:51,127 - INFO - Response preview: Based on the given text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Culex
# E2: Morinda royoc
# relation: Culex mutualistof Morinda royoc
# confidence: 0.9
#
# This pair shows
# 2025-06-26 16:59:52,081 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:52,084 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1.
# E1: Stegastes fuscus
# E2: Diadema antillarum
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This p
# 2025-06-26 16:59:53,284 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:53,288 - INFO - Response preview: After analyzing the text, I found the following interactions:
#
# 1. E1: Macaria signaria
# E2: Tsuga
# relation: E1 eats E2
# confidence: 0.9
#
# This interaction is classified under Predation, as Macaria
# 2025-06-26 16:59:54,117 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:54,121 - INFO - Response preview: Based on the provided text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Cyprinus
# E2: Ranatra chinensis
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This interaction is
# 2025-06-26 16:59:54,804 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:54,807 - INFO - Response preview: Based on the provided text, I've identified a potential interaction between the two entities. Here is the result:
#
# E1: Pseudexentera habrosana
# E2: Notholithocarpus densiflorus
# relation: E1 interac
# 2025-06-26 16:59:55,692 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:55,696 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Andrena trizonata
# E2: Marah oreganus
# relation: E1 mutualistof E2
# confidence: 0.9
#
# This pair is
# 2025-06-26 16:59:56,478 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:56,481 - INFO - Response preview: Based on the provided text, I've identified the following pairs with a clear interaction:
#
# 1. E1: Andrena confederata
# E2: Conium maculatum
# relation: E1 mutualistof E2
# confidence: 0.9
#
# This pair
# 2025-06-26 16:59:57,060 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:57,064 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Phyllonorycter ribefoliae
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 16:59:57,649 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:57,653 - INFO - Response preview: After analyzing the text, I identified a clear interaction between the two entities:
#
# E1: Syndesmis collongistyla
# E2: Lytechinus variegatus
# relation: E1 commensalistof E2
# confidence: 0.9
# 100%|███████████████████████████████████████████| 10/10 [00:07<00:00,  1.27it/s]
# 2025-06-26 16:59:58,234 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 16:59:58,238 - INFO - Response preview: Based on the provided text, I identified the following interaction:
#
# E1: Hydriomena nubilofasciata
# E2: Quercus agrifolia
# relation: E1 eats E2
# confidence: 0.9
# 2025-06-26 17:00:08,153 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:08,157 - INFO - Response preview: Based on the given text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Urochloa brizantha
# E2: Spodoptera frugiperda
# relation: Urochloa brizantha competeswith Spodoptera frug
# 2025-06-26 17:00:08,620 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:08,624 - INFO - Response preview: Based on the provided text, I identified the following interaction:
#
# E1: Closterocerus
# E2: Pyrenochaeta
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 17:00:09,175 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:09,178 - INFO - Response preview: After analyzing the text, I identified a clear interaction between the two entities. Here is the result:
#
# E1: Closterocerus
# E2: Pygostylus falcatus
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 17:00:10,038 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:10,045 - INFO - Response preview: After analyzing the text, I identified the following pairs with a clear interaction:
#
# 1.
# E1: Lytechinus variegatus
# E2: Macrochiron echinicolum
# relation: E1 commensalistof E2
# confidence: 0.9
#
# T
# 2025-06-26 17:00:10,604 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:10,606 - INFO - Response preview: Based on the provided text, I have identified the following interactions:
#
# 1. E1: Closterocerus
# E2: Anatoecus dentatus
# relation: E1 parasiteof E2
# confidence: 0.9
# 2025-06-26 17:00:11,762 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:11,764 - INFO - Response preview: Based on the provided text, the following pairs with a clear interaction are identified:
#
# 1.
# E1: Urochloa eminii
# E2: Zea mays
# relation: Urochloa eminii allelopathof Zea mays
# confidence: 0.9
#
# 2
# 2025-06-26 17:00:12,541 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:12,543 - INFO - Response preview: Based on the provided text, the following pairs have a clear interaction:
#
# 1. E1: Aedes vigilax
# E2: Homo sapiens
# relation: E1 eats E2
# confidence: 0.9
#
# Note: The text explicitly states that Aedes
# 2025-06-26 17:00:13,248 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:13,250 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Epinotia emarginana
# E2: Quercus kelloggii
# relation: E1 competeswith E2
# confidence: 0.8
# 2025-06-26 17:00:14,497 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:14,501 - INFO - Response preview: After analyzing the text, I found the following clear interactions:
#
# 1.
# E1: Pseudopanurgus parvus
# E2: Amphicarpaea bracteata
# relation: Pseudopanurgus parvus mutualistof Amphicarpaea bracteata
# c
# 100%|███████████████████████████████████████████| 10/10 [00:16<00:00,  1.68s/it]
# 2025-06-26 17:00:15,515 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:15,517 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Pseudexentera habrosana
# E2: Platanus
# relation: E1 competeswith E2
# confidence: 0.8
#
# Note that the
# 2025-06-26 17:00:16,372 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:16,375 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Dufourea maura
# E2: Campanula rotundifolia
# relation: Dufourea maura mutualistof Campanula rotund
# 2025-06-26 17:00:17,448 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:17,450 - INFO - Response preview: Based on the given text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Desmodium incanum
# E2: Striga hermonthica
# relation: Desmodium incanum allelopathof Striga hermonthi
# 2025-06-26 17:00:18,610 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:18,613 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Macaria signaria
# E2: Larix
# relation: E1 eats E2
# confidence: 0.9
#
# This interaction is classifi
# 2025-06-26 17:00:19,525 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:19,528 - INFO - Response preview: Based on the provided text, I have identified the following pairs with a clear interaction:
#
# 1.
# E1: Macaria signaria
# E2: Abies balsamea
# relation: Macaria signaria eats Abies balsamea
# confidenc
# 2025-06-26 17:00:20,463 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:20,466 - INFO - Response preview: After analyzing the given text, I identified a clear interaction between the two entities. Here are the results:
#
# 1. E1: Strix aluco
# E2: Picea sitchensis
# relation: E1 commensalistof E2
# confidenc
# 2025-06-26 17:00:21,311 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:21,314 - INFO - Response preview: After analyzing the given text, I identified the following clear interactions:
#
# 1. E1: Lytechinus variegatus
# E2: Syndesmis
# relation: E1 commensalistof E2
# confidence: 0.9
#
# This interaction is an
# 2025-06-26 17:00:22,088 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:22,091 - INFO - Response preview: After analyzing the text, I found the following pairs with a clear interaction:
#
# 1.
# E1: Closterocerus
# E2: Braconidae unspecified
# relation: E1 parasiteof E2
# confidence: 0.9
#
# Note that the text m
# 2025-06-26 17:00:23,287 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:23,291 - INFO - Response preview: Based on the provided text, I have identified the following interaction between the entities:
#
# Text: Macaria signaria has been identified as a consumer of Picea glauca, contributing to top-down contro
# 2025-06-26 17:00:23,823 - INFO - HTTP Request: POST https://api.deepinfra.com/v1/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-06-26 17:00:23,829 - INFO - Response preview: Based on the provided text, I identified the following interaction:
#
# E1: Closterocerus
# E2: Agromyzidae unspecified
# relation: E1 parasiteof E2
# confidence: 0.9
# 100%|███████████████████████████████████████████| 10/10 [00:09<00:00,  1.07it/s]
